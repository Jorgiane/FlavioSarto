# %% [markdown]
# <a href="https://colab.research.google.com/github/FlavioSarto/FlavioSarto/blob/main/trilha7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("ggplot2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(ggplot2)

# %%
ggplot(diamonds, aes(x=carat, y=price)) + geom_point()
# Out:
# plot without title

# %%
ggplot(diamonds, aes(x=carat, y=price)) + geom_point() + ggtitle("análise de diamantes", subtitle = "peso x preço") + xlab("peso do diamante") + ylab("preço do diamante")
# Out:
# plot without title

# %%
ggplot(diamonds, aes(x=carat, y=price)) + geom_point(col="green", size=1) + ggtitle("análise de diamantes", subtitle = "peso x preço") + xlab("peso do diamante") + ylab("preço do diamante")
# Out:
# plot without title

# %%
ggplot(diamonds, aes(x=carat, y=price)) + geom_point(col="darkcyan", aes(size=carat)) + ggtitle("análise de diamantes", subtitle = "peso x preço") + xlab("peso do diamante") + ylab("preço do diamante")
# Out:
# plot without title

# %%
ggplot(diamonds, aes(x=carat, y=price)) + geom_point(aes(col=clarity, size=carat)) + ggtitle("análise de diamantes", subtitle = "peso x preço") + xlab("peso do diamante") + ylab("preço do diamante")
# Out:
# plot without title

# %%
help(theme_bw)
# Out:
# Warning message in seq_len(head.end.idx):
# “first element used of 'length.out' argument”
# ERROR while rich displaying an object: Error in seq_len(head.end.idx): argument must be coercible to non-negative integer
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
# ...

# %%
ggplot(diamonds, aes(x=carat, y=price)) + geom_point(aes(col=clarity, size=carat)) + ggtitle("análise de diamantes", subtitle = "peso x preço") + xlab("peso do diamante") + ylab("preço do diamante") + theme_bw()
# Out:
# plot without title

# %%
ggplot(diamonds, aes(x=carat, y=price)) +
geom_point(aes(col=clarity, size=carat)) +
ggtitle("Análise de Diamantes", subtitle="Peso X Preço") +
xlab("Peso do diamante") +
ylab("Preço do Diamante") +
theme_bw()
# Out:
# plot without title

# %%
ggplot(diamonds, aes(x=carat, y=price)) +
geom_point(aes(col=clarity), size=1) +
ggtitle("Análise de Diamantes", subtitle="Peso X Preço") +
xlab("Peso do diamante") +
ylab("Preço do Diamante") +
geom_smooth(aes(x=carat, y=price, col=clarity)) +
facet_wrap( ~ clarity)
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %%
ggplot(diamonds, aes(x=carat, y=price)) +
geom_point(col="darkcyan", aes(size=carat)) +
ggtitle("Análise de Diamantes", subtitle="Peso X Preço") +
xlab("Peso do diamante") +
ylab("Preço do Diamante")
# Out:
# plot without title

# %%
ggplot(diamonds, aes(x=carat, y=price)) + geom_point() + geom_smooth()
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %%
ggplot(diamonds, aes(x=carat, y=price)) +
geom_point(aes(col=clarity), size=1) +
ggtitle("Análise de Diamantes", subtitle="Peso X Preço") +
xlab("Peso do diamante") +
ylab("Preço do Diamante") +
geom_smooth(aes(x=carat, y=price, col=clarity))
# Out:
# `geom_smooth()` using method = 'gam' and formula 'y ~ s(x, bs = "cs")'
# plot without title

# %%
install.packages ("RColorBrewer")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library ("RColorBrewer")
display.brewer.all()
# Out:
# plot without title

# %%
graficodiamantes <- ggplot(diamonds, aes(x = color, fill = clarity)) +
geom_bar (position = 'fill') +
xlab('cores do diamante \n de D (melhor) até J(pior)') +
ylab('proporções') +
labs(fill = "claridade do diamante \n de I1 (pior) até If(melhor)") +
facet_grid(. ~ cut) +
ggtitle('detalhes dos diamantes!')
graficodiamantes
# Out:
# plot without title
